-- %% [markdown]
-- #### Consultar Datos mediante Unity Catalog usando el espacio de nombre de 3 niveles

-- %%
SELECT * FROM demo_catalog.demo_schema.clientes;

-- %%
-- no puede acceder sino se especifica como arriba
SELECT * FROM clientes;

-- %%
SELECT current_catalog();

-- %%
SHOW CATALOGS;

-- %%
-- en que schema estoy
SELECT current_schema();

-- %%
SHOW SCHEMAS;

-- %%
-- otra forma es especificar asi
USE CATALOG demo_catalog;
USE SCHEMA demo_schema;
SELECT * FROM clientes;

-- %%
-- tablas dentro del schema
SHOW TABLES;

-- %% [markdown]
-- Ahora consulto desde Python

-- %%
%python
display(spark.sql('SHOW TABLES'))

-- %%
%python
df = spark.table('demo_catalog.demo_schema.clientes')

-- %%
%python
display(df)
