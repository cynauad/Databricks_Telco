-- %% [markdown]
-- #### Crear Catalogs y Schemas para el Proyecto
-- 1. Catalog - telco_dev (sin Managed Location)
-- 1. Schemas - bronze, silver y gold (con Managed Location)

-- %%
CREATE CATALOG IF NOT EXISTS telco_dev;

-- %%
USE CATALOG telco_dev;

-- %%
CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION "abfs://bronze@dbsadatabricksext.dfs.core.windows.net/"

-- %%
CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION "abfs://silver@dbsadatabricksext.dfs.core.windows.net/"

-- %%
CREATE SCHEMA IF NOT EXISTS gold
MANAGED LOCATION "abfs://gold@dbsadatabricksext.dfs.core.windows.net/"
